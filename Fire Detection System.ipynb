# %%
import torch

#check if CUDA is available
if torch.cuda.is_available():
  device = torch.device("cuda")
  print("Running on the GPU")
else:
  device = torch.device("cpu")
  print("Running on the CPU")
# Out:
# Running on the GPU

# %%
import cv2
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, GlobalAveragePooling2D, concatenate, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Load the dataset
train_path = 'Train'
test_path = 'Test'
class_names = ['Fire', 'NonFire']
train_data = []
train_labels = []
test_data = []
test_labels = []

# %%
# Load the training data
for class_name in class_names:
    class_path = os.path.join(train_path, class_name)
    for video_name in os.listdir(class_path):
        video_path = os.path.join(class_path, video_name)
        cap = cv2.VideoCapture(video_path)
        while(cap.isOpened()):
            ret, frame = cap.read()
            if ret == False:
                break
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            resized = cv2.resize(gray, (112, 112), interpolation = cv2.INTER_AREA)
            train_data.append(resized.reshape((112, 112, 1)))
            train_labels.append(class_names.index(class_name))

# %%
#Load the testing data
for class_name in class_names:
  class_path = os.path.join(test_path, class_name)
  for video_name in os.listdir(class_path):
    video_path = os.path.join(class_path, video_name)
    cap = cv2.VideoCapture(video_path)
    while(cap.isOpened()):
      ret, frame = cap.read()
      if ret == False:
        break
      gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
      resized = cv2.resize(gray, (112, 112), interpolation = cv2.INTER_AREA)
      test_data.append(resized.reshape((112, 112, 1)))
      test_labels.append(class_names.index(class_name))

# %%
#Convert the data into numpy arrays
train_data = np.array(train_data)
train_labels = np.array(train_labels)
test_data = np.array(test_data)
test_labels = np.array(test_labels)

# %%
#One-hot encode the labels
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
# Define the SA-FDS model
def sa_fds(input_shape, num_classes):
    input_img = Input(shape=input_shape)

    x = Conv2D(32, (3, 3), padding='same', activation='relu')(input_img)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    # Fire module 1
    squeeze1 = Conv2D(8, (1, 1), padding='same', activation='relu')(x)
    expand1 = concatenate([Conv2D(32, (1, 1), padding='same', activation='relu')(squeeze1),
                           Conv2D(32, (3, 3), padding='same', activation='relu')(squeeze1)])
    x = Dropout(0.2)(expand1)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    # Fire module 2
    squeeze2 = Conv2D(8, (1, 1), padding='same', activation='relu')(x)
    expand2 = concatenate([Conv2D(32, (1, 1), padding='same', activation='relu')(squeeze2),
                           Conv2D(32, (3, 3), padding='same', activation='relu')(squeeze2)])
    x = Dropout(0.2)(expand2)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    # Fire module 3
    squeeze3 = Conv2D(8, (1, 1), padding='same', activation='relu')(x)
    expand3 = concatenate([Conv2D(32, (1, 1), padding='same', activation='relu')(squeeze3),
                           Conv2D(32, (3, 3), padding='same', activation='relu')(squeeze3)])
    x = Dropout(0.5)(expand3)

    # Output layer
    x = Conv2D(num_classes, (1, 1), padding='valid')(x)
    x = GlobalAveragePooling2D()(x)
    output = Activation('softmax')(x)

    model = Model(inputs=input_img, outputs=output)
    return model

# %%
# Define the input image size
input_shape = (112, 112, 1)
num_classes = 2

# %%
# Define the batch size and number of epochs
batch_size = 32
epochs = 100

# %%
# Define the optimizer and loss function
optimizer = optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.99, decay=0.001)
loss = 'binary_crossentropy'

# %%
# Define the SA-FDS model
model = sa_fds(input_shape, num_classes)

# %%
#Compile the model
model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

# %%
# Define the data augmentation parameters
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    brightness_range=[0.5, 1.5],
    zoom_range=[0.8, 1.2],
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Create the train and test generators
train_generator = train_datagen.flow(np.array(train_data), np.array(train_labels), batch_size=batch_size)
test_generator = test_datagen.flow(np.array(test_data), np.array(test_labels), batch_size=batch_size)

# %%
# Train the model
model.fit(train_generator, steps_per_epoch=len(train_generator), epochs=epochs, validation_data=test_generator, validation_steps=len(test_generator))
# Out:
# Epoch 1/100
# 2023-04-01 22:22:07.195471: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8600
# 2023-04-01 22:22:07.639709: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2976/2976 [==============================] - 59s 19ms/step - loss: 0.2815 - accuracy: 0.8889 - val_loss: 0.1367 - val_accuracy: 0.9698
# Epoch 2/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.1385 - accuracy: 0.9518 - val_loss: 0.0943 - val_accuracy: 0.9770
# Epoch 3/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.1164 - accuracy: 0.9592 - val_loss: 0.1178 - val_accuracy: 0.9721
# Epoch 4/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.1065 - accuracy: 0.9630 - val_loss: 0.0804 - val_accuracy: 0.9801
# Epoch 5/100
# 2976/2976 [==============================] - 56s 19ms/step - loss: 0.0996 - accuracy: 0.9657 - val_loss: 0.0813 - val_accuracy: 0.9794
# Epoch 6/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0961 - accuracy: 0.9669 - val_loss: 0.0778 - val_accuracy: 0.9803
# Epoch 7/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0927 - accuracy: 0.9687 - val_loss: 0.0959 - val_accuracy: 0.9744
# Epoch 8/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0896 - accuracy: 0.9699 - val_loss: 0.0858 - val_accuracy: 0.9776
# Epoch 9/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0864 - accuracy: 0.9712 - val_loss: 0.0764 - val_accuracy: 0.9791
# Epoch 10/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0861 - accuracy: 0.9711 - val_loss: 0.0903 - val_accuracy: 0.9746
# Epoch 11/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0850 - accuracy: 0.9712 - val_loss: 0.0773 - val_accuracy: 0.9803
# Epoch 12/100
# 2976/2976 [==============================] - 58s 20ms/step - loss: 0.0809 - accuracy: 0.9725 - val_loss: 0.0708 - val_accuracy: 0.9810
# Epoch 13/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0829 - accuracy: 0.9716 - val_loss: 0.0771 - val_accuracy: 0.9787
# Epoch 14/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0832 - accuracy: 0.9724 - val_loss: 0.0788 - val_accuracy: 0.9788
# Epoch 15/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0810 - accuracy: 0.9726 - val_loss: 0.0694 - val_accuracy: 0.9811
# Epoch 16/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0795 - accuracy: 0.9736 - val_loss: 0.0698 - val_accuracy: 0.9808
# Epoch 17/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0776 - accuracy: 0.9741 - val_loss: 0.0688 - val_accuracy: 0.9806
# Epoch 18/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0783 - accuracy: 0.9735 - val_loss: 0.0688 - val_accuracy: 0.9813
# Epoch 19/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0784 - accuracy: 0.9741 - val_loss: 0.0850 - val_accuracy: 0.9768
# Epoch 20/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0761 - accuracy: 0.9743 - val_loss: 0.0748 - val_accuracy: 0.9791
# Epoch 21/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0777 - accuracy: 0.9742 - val_loss: 0.0723 - val_accuracy: 0.9801
# Epoch 22/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0761 - accuracy: 0.9745 - val_loss: 0.0841 - val_accuracy: 0.9759
# Epoch 23/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0776 - accuracy: 0.9745 - val_loss: 0.0659 - val_accuracy: 0.9814
# Epoch 24/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0769 - accuracy: 0.9749 - val_loss: 0.0704 - val_accuracy: 0.9801
# Epoch 25/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0743 - accuracy: 0.9753 - val_loss: 0.0722 - val_accuracy: 0.9800
# Epoch 26/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0766 - accuracy: 0.9749 - val_loss: 0.0663 - val_accuracy: 0.9830
# Epoch 27/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0745 - accuracy: 0.9757 - val_loss: 0.0799 - val_accuracy: 0.9776
# Epoch 28/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0737 - accuracy: 0.9755 - val_loss: 0.0806 - val_accuracy: 0.9765
# Epoch 29/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0741 - accuracy: 0.9753 - val_loss: 0.0746 - val_accuracy: 0.9796
# Epoch 30/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0755 - accuracy: 0.9752 - val_loss: 0.0637 - val_accuracy: 0.9821
# Epoch 31/100
# 2976/2976 [==============================] - 56s 19ms/step - loss: 0.0727 - accuracy: 0.9759 - val_loss: 0.0745 - val_accuracy: 0.9793
# Epoch 32/100
# 2976/2976 [==============================] - 56s 19ms/step - loss: 0.0738 - accuracy: 0.9752 - val_loss: 0.0729 - val_accuracy: 0.9790
# Epoch 33/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0714 - accuracy: 0.9770 - val_loss: 0.0668 - val_accuracy: 0.9809
# Epoch 34/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0730 - accuracy: 0.9760 - val_loss: 0.0635 - val_accuracy: 0.9827
# Epoch 35/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0725 - accuracy: 0.9759 - val_loss: 0.0667 - val_accuracy: 0.9808
# Epoch 36/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0716 - accuracy: 0.9761 - val_loss: 0.0705 - val_accuracy: 0.9789
# Epoch 37/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0723 - accuracy: 0.9760 - val_loss: 0.0620 - val_accuracy: 0.9831
# Epoch 38/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0717 - accuracy: 0.9759 - val_loss: 0.0800 - val_accuracy: 0.9771
# Epoch 39/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0711 - accuracy: 0.9761 - val_loss: 0.0694 - val_accuracy: 0.9802
# Epoch 40/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0732 - accuracy: 0.9760 - val_loss: 0.0630 - val_accuracy: 0.9828
# Epoch 41/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0711 - accuracy: 0.9763 - val_loss: 0.0712 - val_accuracy: 0.9796
# Epoch 42/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0710 - accuracy: 0.9763 - val_loss: 0.0696 - val_accuracy: 0.9798
# Epoch 43/100
# 2976/2976 [==============================] - 56s 19ms/step - loss: 0.0722 - accuracy: 0.9766 - val_loss: 0.0715 - val_accuracy: 0.9794
# Epoch 44/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0700 - accuracy: 0.9772 - val_loss: 0.0694 - val_accuracy: 0.9798
# Epoch 45/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0707 - accuracy: 0.9768 - val_loss: 0.0731 - val_accuracy: 0.9788
# Epoch 46/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0686 - accuracy: 0.9778 - val_loss: 0.0670 - val_accuracy: 0.9810
# Epoch 47/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0700 - accuracy: 0.9767 - val_loss: 0.0721 - val_accuracy: 0.9791
# Epoch 48/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0698 - accuracy: 0.9765 - val_loss: 0.0691 - val_accuracy: 0.9797
# Epoch 49/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0706 - accuracy: 0.9770 - val_loss: 0.0653 - val_accuracy: 0.9820
# Epoch 50/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0688 - accuracy: 0.9772 - val_loss: 0.0645 - val_accuracy: 0.9815
# Epoch 51/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0681 - accuracy: 0.9772 - val_loss: 0.0698 - val_accuracy: 0.9796
# Epoch 52/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0697 - accuracy: 0.9773 - val_loss: 0.0654 - val_accuracy: 0.9814
# Epoch 53/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0691 - accuracy: 0.9770 - val_loss: 0.0695 - val_accuracy: 0.9802
# Epoch 54/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0698 - accuracy: 0.9771 - val_loss: 0.0733 - val_accuracy: 0.9785
# Epoch 55/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0679 - accuracy: 0.9782 - val_loss: 0.0732 - val_accuracy: 0.9785
# Epoch 56/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0696 - accuracy: 0.9771 - val_loss: 0.0725 - val_accuracy: 0.9789
# Epoch 57/100
# 2976/2976 [==============================] - 56s 19ms/step - loss: 0.0695 - accuracy: 0.9770 - val_loss: 0.0697 - val_accuracy: 0.9800
# Epoch 58/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0693 - accuracy: 0.9776 - val_loss: 0.0674 - val_accuracy: 0.9808
# Epoch 59/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0692 - accuracy: 0.9773 - val_loss: 0.0754 - val_accuracy: 0.9780
# Epoch 60/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0680 - accuracy: 0.9779 - val_loss: 0.0665 - val_accuracy: 0.9810
# Epoch 61/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0680 - accuracy: 0.9778 - val_loss: 0.0730 - val_accuracy: 0.9789
# Epoch 62/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0691 - accuracy: 0.9774 - val_loss: 0.0723 - val_accuracy: 0.9790
# Epoch 63/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0680 - accuracy: 0.9778 - val_loss: 0.0742 - val_accuracy: 0.9787
# Epoch 64/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0709 - accuracy: 0.9770 - val_loss: 0.0635 - val_accuracy: 0.9819
# Epoch 65/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0684 - accuracy: 0.9780 - val_loss: 0.0690 - val_accuracy: 0.9797
# Epoch 66/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0669 - accuracy: 0.9780 - val_loss: 0.0720 - val_accuracy: 0.9794
# Epoch 67/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0683 - accuracy: 0.9785 - val_loss: 0.0747 - val_accuracy: 0.9783
# Epoch 68/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0664 - accuracy: 0.9779 - val_loss: 0.0755 - val_accuracy: 0.9784
# Epoch 69/100
# 2976/2976 [==============================] - 56s 19ms/step - loss: 0.0665 - accuracy: 0.9783 - val_loss: 0.0732 - val_accuracy: 0.9787
# Epoch 70/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0664 - accuracy: 0.9781 - val_loss: 0.0708 - val_accuracy: 0.9789
# Epoch 71/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0674 - accuracy: 0.9781 - val_loss: 0.0688 - val_accuracy: 0.9797
# Epoch 72/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0663 - accuracy: 0.9784 - val_loss: 0.0685 - val_accuracy: 0.9807
# Epoch 73/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0662 - accuracy: 0.9785 - val_loss: 0.0646 - val_accuracy: 0.9812
# Epoch 74/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0666 - accuracy: 0.9777 - val_loss: 0.0666 - val_accuracy: 0.9809
# Epoch 75/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0666 - accuracy: 0.9781 - val_loss: 0.0589 - val_accuracy: 0.9838
# Epoch 76/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0655 - accuracy: 0.9782 - val_loss: 0.0714 - val_accuracy: 0.9796
# Epoch 77/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0672 - accuracy: 0.9780 - val_loss: 0.0629 - val_accuracy: 0.9824
# Epoch 78/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0660 - accuracy: 0.9784 - val_loss: 0.0633 - val_accuracy: 0.9816
# Epoch 79/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0663 - accuracy: 0.9780 - val_loss: 0.0719 - val_accuracy: 0.9786
# Epoch 80/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0680 - accuracy: 0.9771 - val_loss: 0.0656 - val_accuracy: 0.9817
# Epoch 81/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0668 - accuracy: 0.9779 - val_loss: 0.0645 - val_accuracy: 0.9816
# Epoch 82/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0658 - accuracy: 0.9788 - val_loss: 0.0645 - val_accuracy: 0.9814
# Epoch 83/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0670 - accuracy: 0.9782 - val_loss: 0.0708 - val_accuracy: 0.9794
# Epoch 84/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0659 - accuracy: 0.9779 - val_loss: 0.0667 - val_accuracy: 0.9805
# Epoch 85/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0648 - accuracy: 0.9787 - val_loss: 0.0671 - val_accuracy: 0.9807
# Epoch 86/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0665 - accuracy: 0.9784 - val_loss: 0.0720 - val_accuracy: 0.9786
# Epoch 87/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0645 - accuracy: 0.9786 - val_loss: 0.0681 - val_accuracy: 0.9806
# Epoch 88/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0656 - accuracy: 0.9784 - val_loss: 0.0673 - val_accuracy: 0.9807
# Epoch 89/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0659 - accuracy: 0.9784 - val_loss: 0.0640 - val_accuracy: 0.9817
# Epoch 90/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0644 - accuracy: 0.9786 - val_loss: 0.0713 - val_accuracy: 0.9790
# Epoch 91/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0631 - accuracy: 0.9792 - val_loss: 0.0698 - val_accuracy: 0.9798
# Epoch 92/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0648 - accuracy: 0.9791 - val_loss: 0.0695 - val_accuracy: 0.9799
# Epoch 93/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0655 - accuracy: 0.9787 - val_loss: 0.0716 - val_accuracy: 0.9790
# Epoch 94/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0658 - accuracy: 0.9784 - val_loss: 0.0638 - val_accuracy: 0.9814
# Epoch 95/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0652 - accuracy: 0.9788 - val_loss: 0.0667 - val_accuracy: 0.9809
# Epoch 96/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0643 - accuracy: 0.9789 - val_loss: 0.0666 - val_accuracy: 0.9809
# Epoch 97/100
# 2976/2976 [==============================] - 58s 19ms/step - loss: 0.0661 - accuracy: 0.9781 - val_loss: 0.0684 - val_accuracy: 0.9796
# Epoch 98/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0653 - accuracy: 0.9789 - val_loss: 0.0594 - val_accuracy: 0.9836
# Epoch 99/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0647 - accuracy: 0.9785 - val_loss: 0.0708 - val_accuracy: 0.9792
# Epoch 100/100
# 2976/2976 [==============================] - 57s 19ms/step - loss: 0.0678 - accuracy: 0.9783 - val_loss: 0.0619 - val_accuracy: 0.9827

# %%
# Test the model
test_loss, test_acc = model.evaluate(test_generator, steps=len(test_generator))
print('Accuracy : ', test_acc)
# Out:
# 1260/1260 [==============================] - 3s 2ms/step - loss: 0.0619 - accuracy: 0.9827
# Accuracy :  0.9826533794403076

# %%
#save the model
model.save('SA-FDS.h5')

# %%
#load the model
from tensorflow.keras.models import load_model
loaded_model = load_model('SA-FDS.h5')

# %% [markdown]
# **Test on New Videos**

# %%
import tkinter as tk
from tkinter import filedialog
from PIL import ImageTk, Image
from tensorflow.keras.models import load_model
import cv2
import os
import numpy as np

# Load the trained model and define other necessary variables
model = load_model('SA-FDS.h5')
class_names = ['Fire', 'Non Fire']
confidence_threshold = 0.8

# Define the thresholds for temporal detection
T1 = 0.7
T2 = 60

# Define variables for temporal detection
F_ref = None

# Create the Tkinter application window
window = tk.Tk()
window.title("FireWatch")
window.geometry("800x600")

# Define custom styles
title_style = {
    "font": ("Arial", 24, "bold"),
    "fg": "black",
}

button_style = {
    "font": ("Arial", 14),
    "padx": 20,
    "pady": 10,
    "bg": "lightblue"
}

output_style = {
    "font": ("Arial", 16),
    "pady": 20
}

video_frame_style = {
    "pady": 10
}

# Create the title label
title_label = tk.Label(window, text="FireWatch", **title_style)
title_label.pack()

# Create the video frame
video_frame = tk.Frame(window, **video_frame_style)
video_frame.pack(pady=10)

# Create the output label
output_label = tk.Label(window, text="", **output_style)
output_label.pack()

# Create the video player function
def play_video():
    video_path = filedialog.askopenfilename(filetypes=[("Video files", "*.mp4")])
    if video_path:
        process_video(video_path)

# Process the video
def process_video(video_path):
    global F_ref

    cap = cv2.VideoCapture(video_path)
    fps = cap.get(cv2.CAP_PROP_FPS)
    video_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    video_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    fourcc = cv2.VideoWriter_fourcc(*'hvc1')
    output_path = "output_video.mp4"
    out = cv2.VideoWriter(output_path, fourcc, fps, (video_width, video_height))

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Perform frame differencing
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        resized = cv2.resize(gray, (112, 112), interpolation=cv2.INTER_AREA)
        x = np.expand_dims(resized, axis=0) / 255.0
        print(x.shape)

        # Pass current frame through the SA-FDS model for prediction
        prediction = model.predict(x)
        cnn_label = class_names[np.argmax(prediction)]
        confidence_score = np.max(prediction)

        # Temporal detection algorithm
        if F_ref is None:
            prediction = cnn_label
        else:
            if confidence_score > T1:
                prediction = cnn_label
            else:
                mse = np.mean((resized.astype("float") - F_ref.astype("float")) ** 2)
                distance = np.sqrt(mse)
                if distance > T2:
                    prediction = 'Fire'
                else:
                    prediction = 'Non Fire'

        # Update F_ref with current frame
        F_ref = resized

        text = f'{prediction} ({confidence_score:.2f})'
        cv2.putText(frame, text, (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA)
        out.write(frame)

        # Display the processed frame in the Tkinter window
        image = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        image = image.resize((video_width, video_height), Image.ANTIALIAS)
        img_tk = ImageTk.PhotoImage(image)
        video_label.configure(image=img_tk)
        video_label.image = img_tk

        # Update the output label
        output_label.configure(text=text)

        window.update()

    cap.release()
    out.release()

# Create the browse button
browse_button = tk.Button(window, text="Browse Video", command=play_video, **button_style)
browse_button.pack()

# Create the video label
video_label = tk.Label(video_frame)
video_label.pack()

# Run the Tkinter event loop
window.mainloop()
# Out:
# (1, 112, 112)
# 1/1 [==============================] - 0s 376ms/step
# C:\Users\Ehtisham Awan\AppData\Local\Temp\ipykernel_6084\1268935117.py:118: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   image = image.resize((video_width, video_height), Image.ANTIALIAS)
# (1, 112, 112)
# 1/1 [==============================] - 0s 32ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 40ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 32ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 32ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 32ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 32ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 63ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 62ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 62ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 47ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step
# (1, 112, 112)
# 1/1 [==============================] - 0s 31ms/step

# %% [markdown]
# **Test on Live Stream from Modified CCTV Camera**

# %%
import cv2
import os
import tensorflow as tf
import tkinter as tk
from PIL import Image, ImageTk
import threading
import numpy as np
from tensorflow.keras.models import load_model

# Load the trained model and define other necessary variables
model = load_model('SA-FDS_Retrain.h5')
class_names = ['Fire', 'Non Fire']
confidence_threshold = 0.8
T1 = 0.7
T2 = 60
F_ref = None

# Create the Tkinter application window
window = tk.Tk()
window.title("FireWatch")
window.geometry("800x600")

# Create custom styles (you can define these as needed)
title_style = {
    "font": ("Arial", 24, "bold"),
    "fg": "black",
}

button_style = {
    "font": ("Arial", 14),
    "padx": 20,
    "pady": 10,
    "bg": "lightblue"
}

video_frame_style = {
    "pady": 10
}

# Create the title label
title_label = tk.Label(window, text="FireWatch", **title_style)
title_label.pack()

# Create a label to display the video feed
video_label = tk.Label(window)
video_label.pack()

# Create a function to display the video stream
def display_video(rtsp_url):
    global F_ref  # Declare F_ref as global

    cap = cv2.VideoCapture(rtsp_url)
    
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        resized = cv2.resize(gray, (112, 112), interpolation=cv2.INTER_AREA)
        x = np.expand_dims(resized, axis=0) / 255.0

        prediction = model.predict(x)
        cnn_label = class_names[np.argmax(prediction)]
        confidence_score = np.max(prediction)

        if F_ref is None:
            prediction = cnn_label
        else:
            if confidence_score > T1:
                prediction = cnn_label
            else:
                mse = np.mean((resized.astype("float") - F_ref.astype("float")) ** 2)
                distance = np.sqrt(mse)
                if distance > T2:
                    prediction = 'Fire'
                else:
                    prediction = 'Non Fire'

        F_ref = resized

        text = f'{prediction} ({confidence_score:.2f})'
        cv2.putText(frame, text, (140, 220), cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 0, 255), 2, cv2.LINE_AA)

        image = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        image = image.resize((640, 480), Image.ANTIALIAS)
        img_tk = ImageTk.PhotoImage(image)
        video_label.configure(image=img_tk)
        video_label.image = img_tk

        window.update()

    cap.release()

# Function to start the live stream
def start_stream():
    rtsp_url = entry_rtsp.get()
    threading.Thread(target=display_video, args=(rtsp_url,), daemon=True).start()

# Create an entry field for entering the RTSP URL
entry_rtsp = tk.Entry(window, font=("Arial", 14))
entry_rtsp.pack()

# Create a start button
start_button = tk.Button(window, text="Start Live Stream", command=start_stream, **button_style)
start_button.pack()

# Run the Tkinter event loop
window.mainloop()
# Out:
# 1/1 [==============================] - 0s 301ms/step
# C:\Users\Ehtisham Awan\AppData\Local\Temp\ipykernel_9780\1281551095.py:86: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   image = image.resize((640, 480), Image.ANTIALIAS)
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
